# %%
import pandas as pd
import numpy as np
import scipy.stats as ss
import sklearn as skl
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Fontconfig warning: ignoring UTF-8: not a valid region tag

# %%
import plotly.offline as py
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as ff

# %%
df = pd.read_csv('IBM_HR.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## We have dropped EmployeeCount (constant value='1'), Over18(constant value='Y') and StandardHours(constant value='80') as they have constant value.

# %%
updated_df = df.drop(['Over18','EmployeeCount','StandardHours'],axis=1)

# %%
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
updated_df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# ...

# %%
updated_df['Attrition']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %% [markdown]
# ## Since Atrribition is not integer, we make it integer by mapping yes=1 and no=0

# %%
updated_df.Attrition.replace(to_replace = dict(Yes = 1, No = 0), inplace = True)

# %%
updated_df.describe()
# Out:
#                Age    Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# count  1470.000000  1470.000000  ...              1470.000000           1470.000000
# mean     36.923810     0.161224  ...                 2.187755              4.123129
# std       9.135373     0.367863  ...                 3.222430              3.568136
# min      18.000000     0.000000  ...                 0.000000              0.000000
# 25%      30.000000     0.000000  ...                 0.000000              2.000000
# 50%      36.000000     0.000000  ...                 1.000000              3.000000
# 75%      43.000000     0.000000  ...                 3.000000              7.000000
# max      60.000000     1.000000  ...                15.000000             17.000000
#
# [8 rows x 25 columns]

# %%
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %% [markdown]
# ##Count of Attrition Values(Yes/No)

# %%
attrition = updated_df[(updated_df['Attrition'] != 0)]
no_attrition = updated_df[(updated_df['Attrition'] == 0)]

trace = go.Bar(x = (len(attrition), len(no_attrition)), y = ['Yes Attrition', 'No Attition'], 
               orientation = 'h', marker=dict(color=['MediumTurquoise', 'tomato']))
                    
fig =go.Figure(data = [trace])
fig.update_layout(autosize=False,width=1000,height=500)
fig.show()

# %%
trace = go.Pie(labels = ['No attrition', 'Yes attrition'], values = updated_df['Attrition'].value_counts(), 
               textfont=dict(size=15), opacity = 1.0,
               marker=dict(colors=['MediumTurquoise', 'tomato']))
           
fig = go.Figure(data = [trace])
fig.update_layout(autosize=False,width=1000,height=500)
fig.show()

# %%
def plot_distribution(var_select, bin_size): 
    corr = updated_df['Attrition'].corr(updated_df[var_select])
    corr = np.round(corr,3)
    tmp1 = attrition[var_select]
    tmp2 = no_attrition[var_select]
    hist_data = [tmp1, tmp2]
    
    group_labels = ['Yes Attrition', 'No Attrition']
    colors = ['MediumTurquoise', 'tomato']

    fig = ff.create_distplot(hist_data, group_labels, colors = colors, show_hist = True, 
                             curve_type='kde', bin_size = bin_size)
    
    fig['layout'].update(title = var_select+' '+'(corr target ='+ str(corr)+')',autosize=False,width=1000,height=500)
    fig.show()

# %%
def barplot(var_select, x_no_numeric) :
    tmp1 = updated_df[(updated_df['Attrition'] != 0)]
    tmp2 = updated_df[(updated_df['Attrition'] == 0)]
    tmp3 = pd.DataFrame(pd.crosstab(updated_df[var_select],updated_df['Attrition']), )
    tmp3['Attr%'] = tmp3[1] / (tmp3[1] + tmp3[0]) * 100
    if x_no_numeric == True  : 
        tmp3 = tmp3.sort_values(1, ascending = False)

    color=['MediumTurquoise', 'tomato']
    trace1 = go.Bar(
        x=tmp1[var_select].value_counts().keys().tolist(),
        y=tmp1[var_select].value_counts().values.tolist(),
        name='Yes Attrition',opacity = 1.0, marker=dict(
        color='red',
        line=dict(color='#000000',width=1)))

    
    trace2 = go.Bar(
        x=tmp2[var_select].value_counts().keys().tolist(),
        y=tmp2[var_select].value_counts().values.tolist(),
        name='No Attrition', opacity = 1.0, marker=dict(
        color='blue',
        line=dict(color='#000000',width=1)))
    
    trace3 =  go.Scatter(   
        x=tmp3.index,
        y=tmp3['Attr%'],
        yaxis = 'y2',
        name='% Attrition', opacity = 0.6, marker=dict(
        color='black',
        line=dict(color='#000000',width=0.5
        )))

    layout = dict(title =  str(var_select),xaxis=dict(), yaxis=dict(title= 'Count'), yaxis2=dict(range= [-0, 75], overlaying= 'y', anchor= 'x', 
                          side= 'right',
                          zeroline=False,
                          showgrid= False, 
                          title= '% Attrition'))

    fig = go.Figure(data=[trace1, trace2, trace3], layout=layout)
    fig.update_layout(autosize=False,width=1000,height=500)
    fig.show()

# %%
plot_distribution('Age', False)
plot_distribution('DailyRate', 100)
plot_distribution('DistanceFromHome', False)
plot_distribution('HourlyRate', False)
plot_distribution('MonthlyIncome', 100)
plot_distribution('MonthlyRate', 100)
plot_distribution('NumCompaniesWorked', False)
plot_distribution('PercentSalaryHike', False)
plot_distribution('TotalWorkingYears', False)
plot_distribution('TrainingTimesLastYear', False)
plot_distribution('YearsAtCompany', False)
plot_distribution('YearsInCurrentRole', False)
plot_distribution('YearsSinceLastPromotion', False)
plot_distribution('YearsWithCurrManager', False)

# %%
barplot('Age', False)
barplot('DistanceFromHome', False)
barplot('NumCompaniesWorked',False)
barplot('PercentSalaryHike', False) 
barplot('TotalWorkingYears', False)
barplot('TrainingTimesLastYear',False)
barplot('YearsAtCompany', False)
barplot('YearsInCurrentRole', False)
barplot('YearsSinceLastPromotion', False)
barplot('YearsWithCurrManager', False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e088d230-6dd6-49bc-aa66-8fb0db25c594" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e088d230-6dd6-49bc-aa66-8fb0db25c594")) {
#                     Plotly.newPlot(
#                         'e088d230-6dd6-49bc-aa66-8fb0db25c594',
# ...

# %%
def plot_pie(var_select) :
    
    colors = ['tomato', 'mediumturquoise', 'lightcoral', 'skyblue', 'lightgrey', 'goldenrod', 'white', 'lightsalmon']
    trace1 = go.Pie(values  = attrition[var_select].value_counts().values.tolist(),
                    labels  = attrition[var_select].value_counts().keys().tolist(),
                    textfont=dict(size=15), opacity = 0.8,
                    hoverinfo = "label+percent+name",
                    domain  = dict(x = [0,.48]),
                    name    = "attrition employes",
                    marker  = dict(colors = colors, line = dict(width = 1.5)))
    trace2 = go.Pie(values  = no_attrition[var_select].value_counts().values.tolist(),
                    labels  = no_attrition[var_select].value_counts().keys().tolist(),
                    textfont=dict(size=15), opacity = 0.8,
                    hoverinfo = "label+percent+name",
                    marker  = dict(colors = colors, line = dict(width = 1.5)),
                    domain  = dict(x = [.52,1]),
                    name    = "Non attrition employes" )

    layout = go.Layout(dict(title = var_select + " distribution in employes attrition ",
                            annotations = [dict(text = "Yes_attrition",
                                                font = dict(size = 13),
                                                showarrow = False,
                                                x = .22, y = -0.1),
                                            dict(text = "No_attrition",
                                                font = dict(size = 13),
                                                showarrow = False,
                                                x = .8,y = -.1)]))
                                          

    fig  = go.Figure(data = [trace1,trace2],layout = layout)
    fig.update_layout(autosize=False,width=1000,height=500)
    fig.show()

# %%
plot_pie("Gender")
plot_pie('OverTime')
plot_pie('BusinessTravel')
plot_pie('JobRole')
plot_pie('Department') 
plot_pie('MaritalStatus') 
plot_pie('EducationField') 
plot_pie('Education') 
plot_pie('EnvironmentSatisfaction')
plot_pie('JobInvolvement')
plot_pie('JobLevel')
plot_pie('JobSatisfaction')
plot_pie('PerformanceRating')
plot_pie('RelationshipSatisfaction')
plot_pie('StockOptionLevel')
plot_pie('WorkLifeBalance')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7df8d9a2-0c2e-4669-83fc-d491079d8e83" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7df8d9a2-0c2e-4669-83fc-d491079d8e83")) {
#                     Plotly.newPlot(
#                         '7df8d9a2-0c2e-4669-83fc-d491079d8e83',
# ...

# %%
barplot('Gender',True)
barplot('OverTime',True)
barplot('BusinessTravel',True)
barplot('JobRole',True)
barplot('Department',True)
barplot('MaritalStatus',True)
barplot('EducationField',True)
barplot('Education',False)
barplot('EnvironmentSatisfaction',False)
barplot('JobInvolvement', False)
barplot('JobLevel',False)
barplot('JobSatisfaction',False)
barplot('PerformanceRating',False)
barplot('RelationshipSatisfaction', False)
barplot('StockOptionLevel', False)
barplot('WorkLifeBalance', False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c299101a-8378-4219-b9fb-fcc964fa8aed" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c299101a-8378-4219-b9fb-fcc964fa8aed")) {
#                     Plotly.newPlot(
#                         'c299101a-8378-4219-b9fb-fcc964fa8aed',
# ...

# %%
Education_sum = updated_df.groupby(['Education']).sum()
Education_sum
# Out:
#              Age  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# Education                    ...
# 1           5468         31  ...                      325                   616
# 2          10395         44  ...                      563                  1127
# 3          20866         99  ...                     1262                  2341
# 4          15634         58  ...                      936                  1752
# 5           1915          5  ...                      130                   225
#
# [5 rows x 24 columns]

# %%
Education = updated_df.groupby(['Attrition', 'Education']).mean()
Education
# Out:
#                            Age  ...  YearsWithCurrManager
# Attrition Education             ...
# 0         1          32.956835  ...              3.841727
#           2          37.126050  ...              4.268908
#           3          37.348837  ...              4.450317
#           4          39.691176  ...              4.482353
#           5          40.348837  ...              4.790698
# 1         1          28.612903  ...              2.645161
#           2          35.431818  ...              2.522727
#           3          32.323232  ...              2.383838
#           4          36.879310  ...              3.931034
#           5          36.000000  ...              3.800000
#
# [10 rows x 23 columns]

# %%
updated_df.groupby(['Education', 'Attrition']).count()
# Out:
#                      Age  ...  YearsWithCurrManager
# Education Attrition       ...
# 1         0          139  ...                   139
#           1           31  ...                    31
# 2         0          238  ...                   238
#           1           44  ...                    44
# 3         0          473  ...                   473
#           1           99  ...                    99
# 4         0          340  ...                   340
#           1           58  ...                    58
# 5         0           43  ...                    43
#           1            5  ...                     5
#
# [10 rows x 30 columns]

# %% [markdown]
# # Hypothesis Testing
#
# ## Test 1
#
# - Ho: µ Education_Attrition == µ Education_Not_Attrition
# - Ha: µ Education_Attrition != µ Education_Not_Attrition

# %%
attrition_df = updated_df[updated_df['Attrition'] == 1]
not_attrition_df = updated_df[updated_df['Attrition'] == 0]

# %%
#stats.shapiro(attrition_df['Education'])
#stats.shapiro(not_attrition_df['Education'])
#stats.ttest_ind(attrition_df['Education'],not_attrition_df['Education'], equal_var = False)
# Out:
# Ttest_indResult(statistic=-1.2177493963259696, pvalue=0.22417128841924902)

# %% [markdown]
# ### Kruskal Test because it is a non-parametric test.

# %%
ss.kruskal(attrition_df['Education'], not_attrition_df['Education'])
# Out:
# KruskalResult(statistic=1.3527640913093548, pvalue=0.2447954753326153)

# %% [markdown]
# ## pvalue > 0.05
#
# ##There appears to be no statistically significant relationship between Attrition and Education, thus we fail reject the null hypothesis.

# %% [markdown]
# # Hypothesis Testing
#
# ## Test 2
#
# Ho: µ Age_Attrition == µ Age_Not_Attrition
#
# Ha: µ Age_Attrition != µ Age_Not_Attrition

# %%
stats.shapiro(attrition_df['Age'])
stats.shapiro(not_attrition_df['Age'])
stats.ttest_ind(attrition_df['Age'], not_attrition_df['Age'], equal_var = False)
ss.kruskal(attrition_df['Age'], not_attrition_df['Age'])
# Out:
# KruskalResult(statistic=43.06268844023747, pvalue=5.3013684961038114e-11)

# %% [markdown]
# ## pvalue < 0.05
#
# ##There appears to be a statistically significant relationship between Attrition and the Age, thus we can reject the null hypothesis.

# %% [markdown]
# # Hypothesis Testing
#
# ## Test 3
#
# Ho: µ Job_Satisfaction_Attrition == µ Job_Satisfaction_Not_Attrition
#
# Ha: µ Job_Satisfaction_Attrition != µ Job_Satisfaction_Not_Attrition

# %%
stats.shapiro(attrition_df['JobSatisfaction'])
stats.shapiro(not_attrition_df['JobSatisfaction'])
stats.ttest_ind(attrition_df['JobSatisfaction'], not_attrition_df['JobSatisfaction'], equal_var = False)
ss.kruskal(attrition_df['JobSatisfaction'], not_attrition_df['JobSatisfaction'])
# Out:
# KruskalResult(statistic=15.568947932935844, pvalue=7.955037680315368e-05)

# %% [markdown]
# ##pvalue < 0.05
#
# ##There appears to be a statistically significant relationship between Attrition and Job Satisfaction, thus we can reject the null hypothesis.

# %%
updated_df.to_csv ('updated_IBM_HR.csv', header=True)
